# %% [markdown]
# Day 10: Modules and libraries
# Learn importing modules and using built-in libraries
# Write a program that uses Python's standard libraries to solve a problem.

# %% [markdown]
# Python standard library - collection of exact syntax, token and semantics of Python.

# %% [markdown]
# Important Python Libraries

# %%
#Matplotlib - numerical plotting lib, helps with data analysis
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('Some numbers')
plt.show()

# %%
#Pandas - used for data manipulation and analysis
import pandas as pd

#Creating a dataframe
data = {'col1':[1, 2, 3], 'col2':['Musa', 'Jane', 'Jackie']}
df = pd.DataFrame(data)

#Display dataframe
print(df)
# Out:
#    col1    col2
# 0     1    Musa
# 1     2    Jane
# 2     3  Jackie

# %%
#Numpy - advanced math functions and scientific computing package
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

print(arr)

print(type(arr))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>
